# %%
# !sudo apt install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 49 not upgraded.
# Need to get 4,795 kB of archives.
# After this operation, 15.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-eng all 4.00~git24-0e00fe6-1.2 [1,588 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-osd all 4.00~git24-0e00fe6-1.2 [2,989 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr amd64 4.00~git2288-10f4998a-2 [218 kB]
# Fetched 4,795 kB in 1s (3,384 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package tesseract-ocr-eng.
# (Reading database ... 155639 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-eng_4.00~git24-0e00fe6-1.2_all.deb ...
# Unpacking tesseract-ocr-eng (4.00~git24-0e00fe6-1.2) ...
# Selecting previously unselected package tesseract-ocr-osd.
# Preparing to unpack .../tesseract-ocr-osd_4.00~git24-0e00fe6-1.2_all.deb ...
# Unpacking tesseract-ocr-osd (4.00~git24-0e00fe6-1.2) ...
# Selecting previously unselected package tesseract-ocr.
# Preparing to unpack .../tesseract-ocr_4.00~git2288-10f4998a-2_amd64.deb ...
# Unpacking tesseract-ocr (4.00~git2288-10f4998a-2) ...
# Setting up tesseract-ocr-osd (4.00~git24-0e00fe6-1.2) ...
# Setting up tesseract-ocr-eng (4.00~git24-0e00fe6-1.2) ...
# Setting up tesseract-ocr (4.00~git2288-10f4998a-2) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !mkdir fonts output train

# %%
font_name = 'Baby Shower'

# %%
# !git clone https://github.com/tesseract-ocr/langdata_lstm
# Out:
# Cloning into 'langdata_lstm'...
# remote: Enumerating objects: 2003, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 2003 (delta 21), reused 37 (delta 16), pack-reused 1954
# Receiving objects: 100% (2003/2003), 1.19 GiB | 24.45 MiB/s, done.
# Resolving deltas: 100% (956/956), done.
# Checking out files: 100% (1237/1237), done.

# %%
# !wget https://github.com/tesseract-ocr/tesseract/archive/refs/heads/4.1.zip
# Out:
# --2022-07-01 11:50:42--  https://github.com/tesseract-ocr/tesseract/archive/refs/heads/4.1.zip
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/tesseract-ocr/tesseract/zip/refs/heads/4.1 [following]
# --2022-07-01 11:50:42--  https://codeload.github.com/tesseract-ocr/tesseract/zip/refs/heads/4.1
# Resolving codeload.github.com (codeload.github.com)... 140.82.114.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.114.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘4.1.zip’
#
# 4.1.zip                 [  <=>               ]   2.43M  6.70MB/s    in 0.4s
#
# 2022-07-01 11:50:43 (6.70 MB/s) - ‘4.1.zip’ saved [2543962]

# %%
# !unzip tesseract.zip
# Out:
# Archive:  tesseract.zip
# 82a7a87b3bc159ef4607adea86100b3c09f406e8
#    creating: tesseract-4.1/
#   inflating: tesseract-4.1/.clang-format
#    creating: tesseract-4.1/.github/
#   inflating: tesseract-4.1/.github/ISSUE_TEMPLATE.md
#   inflating: tesseract-4.1/.gitignore
#   inflating: tesseract-4.1/.gitmodules
#   inflating: tesseract-4.1/.lgtm.yml
#   inflating: tesseract-4.1/.travis.yml
#   inflating: tesseract-4.1/AUTHORS
#   inflating: tesseract-4.1/CMakeLists.txt
#   inflating: tesseract-4.1/CONTRIBUTING.md
#   inflating: tesseract-4.1/ChangeLog
#   inflating: tesseract-4.1/Dockerfile
#   inflating: tesseract-4.1/INSTALL
#   inflating: tesseract-4.1/INSTALL.GIT.md
#   inflating: tesseract-4.1/LICENSE
#   inflating: tesseract-4.1/Makefile.am
#   inflating: tesseract-4.1/README.md
#  extracting: tesseract-4.1/VERSION
#    creating: tesseract-4.1/abseil/
#   inflating: tesseract-4.1/appveyor.yml
#   inflating: tesseract-4.1/autogen.sh
#    creating: tesseract-4.1/cmake/
#   inflating: tesseract-4.1/cmake/AddCompilerFlag.cmake
#   inflating: tesseract-4.1/cmake/BuildFunctions.cmake
#   inflating: tesseract-4.1/cmake/CheckCCompilerFlag.cmake
#   inflating: tesseract-4.1/cmake/CheckCXXCompilerFlag.cmake
#   inflating: tesseract-4.1/cmake/Configure.cmake
#   inflating: tesseract-4.1/cmake/OptimizeForArchitecture.cmake
#   inflating: tesseract-4.1/cmake/SourceGroups.cmake
#    creating: tesseract-4.1/cmake/templates/
#   inflating: tesseract-4.1/cmake/templates/TesseractConfig-version.cmake.in
#   inflating: tesseract-4.1/cmake/templates/TesseractConfig.cmake.in
#   inflating: tesseract-4.1/cmake/templates/cmake_uninstall.cmake.in
#   inflating: tesseract-4.1/configure.ac
#   inflating: tesseract-4.1/cppan.yml
#    creating: tesseract-4.1/doc/
#   inflating: tesseract-4.1/doc/Doxyfile
#   inflating: tesseract-4.1/doc/Makefile.am
#   inflating: tesseract-4.1/doc/ambiguous_words.1.asc
#   inflating: tesseract-4.1/doc/classifier_tester.1.asc
#   inflating: tesseract-4.1/doc/cntraining.1.asc
#   inflating: tesseract-4.1/doc/combine_lang_model.1.asc
#   inflating: tesseract-4.1/doc/combine_tessdata.1.asc
#   inflating: tesseract-4.1/doc/dawg2wordlist.1.asc
#   inflating: tesseract-4.1/doc/generate_manpages.sh
#   inflating: tesseract-4.1/doc/lstmeval.1.asc
#   inflating: tesseract-4.1/doc/lstmtraining.1.asc
#   inflating: tesseract-4.1/doc/merge_unicharsets.1.asc
#   inflating: tesseract-4.1/doc/mftraining.1.asc
#   inflating: tesseract-4.1/doc/set_unicharset_properties.1.asc
#   inflating: tesseract-4.1/doc/shapeclustering.1.asc
#   inflating: tesseract-4.1/doc/tesseract.1.asc
#   inflating: tesseract-4.1/doc/tesseract.bib
#   inflating: tesseract-4.1/doc/text2image.1.asc
#   inflating: tesseract-4.1/doc/unicharambigs.5.asc
#   inflating: tesseract-4.1/doc/unicharset.5.asc
#   inflating: tesseract-4.1/doc/unicharset_extractor.1.asc
#   inflating: tesseract-4.1/doc/wordlist2dawg.1.asc
#  extracting: tesseract-4.1/docker-compose.yml
#    creating: tesseract-4.1/googletest/
#    creating: tesseract-4.1/java/
#   inflating: tesseract-4.1/java/Makefile.am
#   inflating: tesseract-4.1/java/Manifest.txt
#    creating: tesseract-4.1/java/com/
#  extracting: tesseract-4.1/java/com/Makefile.am
#    creating: tesseract-4.1/java/com/google/
#  extracting: tesseract-4.1/java/com/google/Makefile.am
#    creating: tesseract-4.1/java/com/google/scrollview/
#   inflating: tesseract-4.1/java/com/google/scrollview/Makefile.am
#   inflating: tesseract-4.1/java/com/google/scrollview/ScrollView.java
#    creating: tesseract-4.1/java/com/google/scrollview/events/
#   inflating: tesseract-4.1/java/com/google/scrollview/events/Makefile.am
#   inflating: tesseract-4.1/java/com/google/scrollview/events/SVEvent.java
#   inflating: tesseract-4.1/java/com/google/scrollview/events/SVEventHandler.java
#   inflating: tesseract-4.1/java/com/google/scrollview/events/SVEventType.java
#    creating: tesseract-4.1/java/com/google/scrollview/ui/
#   inflating: tesseract-4.1/java/com/google/scrollview/ui/Makefile.am
#   inflating: tesseract-4.1/java/com/google/scrollview/ui/SVAbstractMenuItem.java
#   inflating: tesseract-4.1/java/com/google/scrollview/ui/SVCheckboxMenuItem.java
#   inflating: tesseract-4.1/java/com/google/scrollview/ui/SVEmptyMenuItem.java
#   inflating: tesseract-4.1/java/com/google/scrollview/ui/SVImageHandler.java
#   inflating: tesseract-4.1/java/com/google/scrollview/ui/SVMenuBar.java
#   inflating: tesseract-4.1/java/com/google/scrollview/ui/SVMenuItem.java
#   inflating: tesseract-4.1/java/com/google/scrollview/ui/SVPopupMenu.java
#   inflating: tesseract-4.1/java/com/google/scrollview/ui/SVSubMenuItem.java
#   inflating: tesseract-4.1/java/com/google/scrollview/ui/SVWindow.java
#    creating: tesseract-4.1/m4/
#   inflating: tesseract-4.1/m4/ax_check_compile_flag.m4
#   inflating: tesseract-4.1/m4/ax_split_version.m4
#    creating: tesseract-4.1/snap/
#   inflating: tesseract-4.1/snap/snapcraft.yaml
#    creating: tesseract-4.1/src/
#    creating: tesseract-4.1/src/api/
#   inflating: tesseract-4.1/src/api/Makefile.am
#   inflating: tesseract-4.1/src/api/altorenderer.cpp
#   inflating: tesseract-4.1/src/api/apitypes.h
#   inflating: tesseract-4.1/src/api/baseapi.cpp
#   inflating: tesseract-4.1/src/api/baseapi.h
#   inflating: tesseract-4.1/src/api/capi.cpp
#   inflating: tesseract-4.1/src/api/capi.h
#   inflating: tesseract-4.1/src/api/hocrrenderer.cpp
#   inflating: tesseract-4.1/src/api/lstmboxrenderer.cpp
#   inflating: tesseract-4.1/src/api/pdfrenderer.cpp
#   inflating: tesseract-4.1/src/api/renderer.cpp
#   inflating: tesseract-4.1/src/api/renderer.h
#   inflating: tesseract-4.1/src/api/tess_version.h.in
#   inflating: tesseract-4.1/src/api/tesseractmain.cpp
#   inflating: tesseract-4.1/src/api/wordstrboxrenderer.cpp
#    creating: tesseract-4.1/src/arch/
#   inflating: tesseract-4.1/src/arch/Makefile.am
#   inflating: tesseract-4.1/src/arch/dotproduct.cpp
#   inflating: tesseract-4.1/src/arch/dotproduct.h
#   inflating: tesseract-4.1/src/arch/dotproductavx.cpp
#   inflating: tesseract-4.1/src/arch/dotproductfma.cpp
#   inflating: tesseract-4.1/src/arch/dotproductsse.cpp
#   inflating: tesseract-4.1/src/arch/intsimdmatrix.cpp
#   inflating: tesseract-4.1/src/arch/intsimdmatrix.h
#   inflating: tesseract-4.1/src/arch/intsimdmatrixavx2.cpp
#   inflating: tesseract-4.1/src/arch/intsimdmatrixsse.cpp
#   inflating: tesseract-4.1/src/arch/simddetect.cpp
#   inflating: tesseract-4.1/src/arch/simddetect.h
#    creating: tesseract-4.1/src/ccmain/
#   inflating: tesseract-4.1/src/ccmain/Makefile.am
#   inflating: tesseract-4.1/src/ccmain/adaptions.cpp
#   inflating: tesseract-4.1/src/ccmain/applybox.cpp
#   inflating: tesseract-4.1/src/ccmain/control.cpp
#   inflating: tesseract-4.1/src/ccmain/control.h
#   inflating: tesseract-4.1/src/ccmain/docqual.cpp
#   inflating: tesseract-4.1/src/ccmain/docqual.h
#   inflating: tesseract-4.1/src/ccmain/equationdetect.cpp
#   inflating: tesseract-4.1/src/ccmain/equationdetect.h
#   inflating: tesseract-4.1/src/ccmain/fixspace.cpp
#   inflating: tesseract-4.1/src/ccmain/fixspace.h
#   inflating: tesseract-4.1/src/ccmain/fixxht.cpp
#   inflating: tesseract-4.1/src/ccmain/linerec.cpp
#   inflating: tesseract-4.1/src/ccmain/ltrresultiterator.cpp
#   inflating: tesseract-4.1/src/ccmain/ltrresultiterator.h
#   inflating: tesseract-4.1/src/ccmain/mutableiterator.cpp
#   inflating: tesseract-4.1/src/ccmain/mutableiterator.h
#   inflating: tesseract-4.1/src/ccmain/osdetect.cpp
#   inflating: tesseract-4.1/src/ccmain/osdetect.h
#   inflating: tesseract-4.1/src/ccmain/output.cpp
#   inflating: tesseract-4.1/src/ccmain/output.h
#   inflating: tesseract-4.1/src/ccmain/pageiterator.cpp
#   inflating: tesseract-4.1/src/ccmain/pageiterator.h
#   inflating: tesseract-4.1/src/ccmain/pagesegmain.cpp
#   inflating: tesseract-4.1/src/ccmain/pagewalk.cpp
#   inflating: tesseract-4.1/src/ccmain/par_control.cpp
#   inflating: tesseract-4.1/src/ccmain/paragraphs.cpp
#   inflating: tesseract-4.1/src/ccmain/paragraphs.h
#   inflating: tesseract-4.1/src/ccmain/paragraphs_internal.h
#   inflating: tesseract-4.1/src/ccmain/paramsd.cpp
#   inflating: tesseract-4.1/src/ccmain/paramsd.h
#   inflating: tesseract-4.1/src/ccmain/pgedit.cpp
#   inflating: tesseract-4.1/src/ccmain/pgedit.h
#   inflating: tesseract-4.1/src/ccmain/recogtraining.cpp
#   inflating: tesseract-4.1/src/ccmain/reject.cpp
#   inflating: tesseract-4.1/src/ccmain/reject.h
#   inflating: tesseract-4.1/src/ccmain/resultiterator.cpp
#   inflating: tesseract-4.1/src/ccmain/resultiterator.h
#   inflating: tesseract-4.1/src/ccmain/superscript.cpp
#   inflating: tesseract-4.1/src/ccmain/tessbox.cpp
#   inflating: tesseract-4.1/src/ccmain/tessedit.cpp
#   inflating: tesseract-4.1/src/ccmain/tesseractclass.cpp
#   inflating: tesseract-4.1/src/ccmain/tesseractclass.h
#   inflating: tesseract-4.1/src/ccmain/tessvars.cpp
#   inflating: tesseract-4.1/src/ccmain/tessvars.h
#   inflating: tesseract-4.1/src/ccmain/tfacepp.cpp
#   inflating: tesseract-4.1/src/ccmain/thresholder.cpp
#   inflating: tesseract-4.1/src/ccmain/thresholder.h
#   inflating: tesseract-4.1/src/ccmain/werdit.cpp
#   inflating: tesseract-4.1/src/ccmain/werdit.h
#    creating: tesseract-4.1/src/ccstruct/
#   inflating: tesseract-4.1/src/ccstruct/Makefile.am
#   inflating: tesseract-4.1/src/ccstruct/blamer.cpp
#   inflating: tesseract-4.1/src/ccstruct/blamer.h
#   inflating: tesseract-4.1/src/ccstruct/blobbox.cpp
#   inflating: tesseract-4.1/src/ccstruct/blobbox.h
#   inflating: tesseract-4.1/src/ccstruct/blobs.cpp
#   inflating: tesseract-4.1/src/ccstruct/blobs.h
#   inflating: tesseract-4.1/src/ccstruct/blread.cpp
#   inflating: tesseract-4.1/src/ccstruct/blread.h
#   inflating: tesseract-4.1/src/ccstruct/boxread.cpp
#   inflating: tesseract-4.1/src/ccstruct/boxread.h
#   inflating: tesseract-4.1/src/ccstruct/boxword.cpp
#   inflating: tesseract-4.1/src/ccstruct/boxword.h
#   inflating: tesseract-4.1/src/ccstruct/ccstruct.cpp
#   inflating: tesseract-4.1/src/ccstruct/ccstruct.h
#   inflating: tesseract-4.1/src/ccstruct/coutln.cpp
#   inflating: tesseract-4.1/src/ccstruct/coutln.h
#   inflating: tesseract-4.1/src/ccstruct/crakedge.h
#   inflating: tesseract-4.1/src/ccstruct/debugpixa.h
#   inflating: tesseract-4.1/src/ccstruct/detlinefit.cpp
#   inflating: tesseract-4.1/src/ccstruct/detlinefit.h
#   inflating: tesseract-4.1/src/ccstruct/dppoint.cpp
#   inflating: tesseract-4.1/src/ccstruct/dppoint.h
#   inflating: tesseract-4.1/src/ccstruct/fontinfo.cpp
#   inflating: tesseract-4.1/src/ccstruct/fontinfo.h
#   inflating: tesseract-4.1/src/ccstruct/imagedata.cpp
#   inflating: tesseract-4.1/src/ccstruct/imagedata.h
#   inflating: tesseract-4.1/src/ccstruct/linlsq.cpp
#   inflating: tesseract-4.1/src/ccstruct/linlsq.h
#   inflating: tesseract-4.1/src/ccstruct/matrix.cpp
#   inflating: tesseract-4.1/src/ccstruct/matrix.h
#   inflating: tesseract-4.1/src/ccstruct/mod128.cpp
#   inflating: tesseract-4.1/src/ccstruct/mod128.h
#   inflating: tesseract-4.1/src/ccstruct/normalis.cpp
#   inflating: tesseract-4.1/src/ccstruct/normalis.h
#   inflating: tesseract-4.1/src/ccstruct/ocrblock.cpp
#   inflating: tesseract-4.1/src/ccstruct/ocrblock.h
#   inflating: tesseract-4.1/src/ccstruct/ocrpara.cpp
#   inflating: tesseract-4.1/src/ccstruct/ocrpara.h
#   inflating: tesseract-4.1/src/ccstruct/ocrrow.cpp
#   inflating: tesseract-4.1/src/ccstruct/ocrrow.h
#   inflating: tesseract-4.1/src/ccstruct/otsuthr.cpp
#   inflating: tesseract-4.1/src/ccstruct/otsuthr.h
#   inflating: tesseract-4.1/src/ccstruct/pageres.cpp
#   inflating: tesseract-4.1/src/ccstruct/pageres.h
#   inflating: tesseract-4.1/src/ccstruct/params_training_featdef.cpp
#   inflating: tesseract-4.1/src/ccstruct/params_training_featdef.h
#   inflating: tesseract-4.1/src/ccstruct/pdblock.cpp
#   inflating: tesseract-4.1/src/ccstruct/pdblock.h
#   inflating: tesseract-4.1/src/ccstruct/points.cpp
#   inflating: tesseract-4.1/src/ccstruct/points.h
#   inflating: tesseract-4.1/src/ccstruct/polyaprx.cpp
#   inflating: tesseract-4.1/src/ccstruct/polyaprx.h
#   inflating: tesseract-4.1/src/ccstruct/polyblk.cpp
#   inflating: tesseract-4.1/src/ccstruct/polyblk.h
#   inflating: tesseract-4.1/src/ccstruct/publictypes.cpp
#   inflating: tesseract-4.1/src/ccstruct/publictypes.h
#   inflating: tesseract-4.1/src/ccstruct/quadlsq.cpp
#   inflating: tesseract-4.1/src/ccstruct/quadlsq.h
#   inflating: tesseract-4.1/src/ccstruct/quadratc.h
#   inflating: tesseract-4.1/src/ccstruct/quspline.cpp
#   inflating: tesseract-4.1/src/ccstruct/quspline.h
#   inflating: tesseract-4.1/src/ccstruct/ratngs.cpp
#   inflating: tesseract-4.1/src/ccstruct/ratngs.h
#   inflating: tesseract-4.1/src/ccstruct/rect.cpp
#   inflating: tesseract-4.1/src/ccstruct/rect.h
#   inflating: tesseract-4.1/src/ccstruct/rejctmap.cpp
#   inflating: tesseract-4.1/src/ccstruct/rejctmap.h
#   inflating: tesseract-4.1/src/ccstruct/seam.cpp
#   inflating: tesseract-4.1/src/ccstruct/seam.h
#   inflating: tesseract-4.1/src/ccstruct/split.cpp
#   inflating: tesseract-4.1/src/ccstruct/split.h
#   inflating: tesseract-4.1/src/ccstruct/statistc.cpp
#   inflating: tesseract-4.1/src/ccstruct/statistc.h
#   inflating: tesseract-4.1/src/ccstruct/stepblob.cpp
#   inflating: tesseract-4.1/src/ccstruct/stepblob.h
#   inflating: tesseract-4.1/src/ccstruct/werd.cpp
#   inflating: tesseract-4.1/src/ccstruct/werd.h
#    creating: tesseract-4.1/src/ccutil/
#   inflating: tesseract-4.1/src/ccutil/Makefile.am
#   inflating: tesseract-4.1/src/ccutil/ambigs.cpp
#   inflating: tesseract-4.1/src/ccutil/ambigs.h
#   inflating: tesseract-4.1/src/ccutil/bits16.h
#   inflating: tesseract-4.1/src/ccutil/bitvector.cpp
#   inflating: tesseract-4.1/src/ccutil/bitvector.h
#   inflating: tesseract-4.1/src/ccutil/ccutil.cpp
#   inflating: tesseract-4.1/src/ccutil/ccutil.h
#   inflating: tesseract-4.1/src/ccutil/clst.cpp
#   inflating: tesseract-4.1/src/ccutil/clst.h
#   inflating: tesseract-4.1/src/ccutil/doubleptr.h
#   inflating: tesseract-4.1/src/ccutil/elst.cpp
#   inflating: tesseract-4.1/src/ccutil/elst.h
#   inflating: tesseract-4.1/src/ccutil/elst2.cpp
#   inflating: tesseract-4.1/src/ccutil/elst2.h
#   inflating: tesseract-4.1/src/ccutil/errcode.cpp
#   inflating: tesseract-4.1/src/ccutil/errcode.h
#   inflating: tesseract-4.1/src/ccutil/fileerr.h
#   inflating: tesseract-4.1/src/ccutil/genericheap.h
#   inflating: tesseract-4.1/src/ccutil/genericvector.h
#   inflating: tesseract-4.1/src/ccutil/globaloc.cpp
#   inflating: tesseract-4.1/src/ccutil/globaloc.h
#   inflating: tesseract-4.1/src/ccutil/helpers.h
#   inflating: tesseract-4.1/src/ccutil/host.h
#   inflating: tesseract-4.1/src/ccutil/indexmapbidi.cpp
#   inflating: tesseract-4.1/src/ccutil/indexmapbidi.h
#   inflating: tesseract-4.1/src/ccutil/kdpair.h
#   inflating: tesseract-4.1/src/ccutil/lsterr.h
#   inflating: tesseract-4.1/src/ccutil/mainblk.cpp
#   inflating: tesseract-4.1/src/ccutil/object_cache.h
#   inflating: tesseract-4.1/src/ccutil/ocrclass.h
#   inflating: tesseract-4.1/src/ccutil/params.cpp
#   inflating: tesseract-4.1/src/ccutil/params.h
#   inflating: tesseract-4.1/src/ccutil/platform.h
#   inflating: tesseract-4.1/src/ccutil/qrsequence.h
#   inflating: tesseract-4.1/src/ccutil/scanutils.cpp
#   inflating: tesseract-4.1/src/ccutil/scanutils.h
#   inflating: tesseract-4.1/src/ccutil/serialis.cpp
#   inflating: tesseract-4.1/src/ccutil/serialis.h
#   inflating: tesseract-4.1/src/ccutil/sorthelper.h
#   inflating: tesseract-4.1/src/ccutil/strngs.cpp
#   inflating: tesseract-4.1/src/ccutil/strngs.h
#   inflating: tesseract-4.1/src/ccutil/tesscallback.h
#   inflating: tesseract-4.1/src/ccutil/tessdatamanager.cpp
#   inflating: tesseract-4.1/src/ccutil/tessdatamanager.h
#   inflating: tesseract-4.1/src/ccutil/tprintf.cpp
#   inflating: tesseract-4.1/src/ccutil/tprintf.h
#   inflating: tesseract-4.1/src/ccutil/unichar.cpp
#   inflating: tesseract-4.1/src/ccutil/unichar.h
#   inflating: tesseract-4.1/src/ccutil/unicharcompress.cpp
#   inflating: tesseract-4.1/src/ccutil/unicharcompress.h
#   inflating: tesseract-4.1/src/ccutil/unicharmap.cpp
#   inflating: tesseract-4.1/src/ccutil/unicharmap.h
#   inflating: tesseract-4.1/src/ccutil/unicharset.cpp
#   inflating: tesseract-4.1/src/ccutil/unicharset.h
#   inflating: tesseract-4.1/src/ccutil/unicity_table.h
#   inflating: tesseract-4.1/src/ccutil/unicodes.cpp
#   inflating: tesseract-4.1/src/ccutil/unicodes.h
#   inflating: tesseract-4.1/src/ccutil/universalambigs.cpp
#   inflating: tesseract-4.1/src/ccutil/universalambigs.h
#    creating: tesseract-4.1/src/classify/
#   inflating: tesseract-4.1/src/classify/Makefile.am
#   inflating: tesseract-4.1/src/classify/adaptive.cpp
#   inflating: tesseract-4.1/src/classify/adaptive.h
#   inflating: tesseract-4.1/src/classify/adaptmatch.cpp
#   inflating: tesseract-4.1/src/classify/blobclass.cpp
#   inflating: tesseract-4.1/src/classify/blobclass.h
#   inflating: tesseract-4.1/src/classify/classify.cpp
#   inflating: tesseract-4.1/src/classify/classify.h
#   inflating: tesseract-4.1/src/classify/cluster.cpp
#   inflating: tesseract-4.1/src/classify/cluster.h
#   inflating: tesseract-4.1/src/classify/clusttool.cpp
#   inflating: tesseract-4.1/src/classify/clusttool.h
#   inflating: tesseract-4.1/src/classify/cutoffs.cpp
#   inflating: tesseract-4.1/src/classify/featdefs.cpp
#   inflating: tesseract-4.1/src/classify/featdefs.h
#   inflating: tesseract-4.1/src/classify/float2int.cpp
#   inflating: tesseract-4.1/src/classify/float2int.h
#   inflating: tesseract-4.1/src/classify/fpoint.cpp
#   inflating: tesseract-4.1/src/classify/fpoint.h
#   inflating: tesseract-4.1/src/classify/intfeaturedist.cpp
#   inflating: tesseract-4.1/src/classify/intfeaturedist.h
#   inflating: tesseract-4.1/src/classify/intfeaturemap.cpp
#   inflating: tesseract-4.1/src/classify/intfeaturemap.h
#   inflating: tesseract-4.1/src/classify/intfeaturespace.cpp
#   inflating: tesseract-4.1/src/classify/intfeaturespace.h
#   inflating: tesseract-4.1/src/classify/intfx.cpp
#   inflating: tesseract-4.1/src/classify/intfx.h
#   inflating: tesseract-4.1/src/classify/intmatcher.cpp
#   inflating: tesseract-4.1/src/classify/intmatcher.h
#   inflating: tesseract-4.1/src/classify/intproto.cpp
#   inflating: tesseract-4.1/src/classify/intproto.h
#   inflating: tesseract-4.1/src/classify/kdtree.cpp
#   inflating: tesseract-4.1/src/classify/kdtree.h
#   inflating: tesseract-4.1/src/classify/mf.cpp
#   inflating: tesseract-4.1/src/classify/mf.h
#   inflating: tesseract-4.1/src/classify/mfdefs.cpp
#   inflating: tesseract-4.1/src/classify/mfdefs.h
#   inflating: tesseract-4.1/src/classify/mfoutline.cpp
#   inflating: tesseract-4.1/src/classify/mfoutline.h
#   inflating: tesseract-4.1/src/classify/mfx.cpp
#   inflating: tesseract-4.1/src/classify/mfx.h
#   inflating: tesseract-4.1/src/classify/normfeat.cpp
#   inflating: tesseract-4.1/src/classify/normfeat.h
#   inflating: tesseract-4.1/src/classify/normmatch.cpp
#   inflating: tesseract-4.1/src/classify/normmatch.h
#   inflating: tesseract-4.1/src/classify/ocrfeatures.cpp
#   inflating: tesseract-4.1/src/classify/ocrfeatures.h
#   inflating: tesseract-4.1/src/classify/outfeat.cpp
#   inflating: tesseract-4.1/src/classify/outfeat.h
#   inflating: tesseract-4.1/src/classify/picofeat.cpp
#   inflating: tesseract-4.1/src/classify/picofeat.h
#   inflating: tesseract-4.1/src/classify/protos.cpp
#   inflating: tesseract-4.1/src/classify/protos.h
#   inflating: tesseract-4.1/src/classify/sampleiterator.cpp
#   inflating: tesseract-4.1/src/classify/sampleiterator.h
#   inflating: tesseract-4.1/src/classify/shapeclassifier.cpp
#   inflating: tesseract-4.1/src/classify/shapeclassifier.h
#   inflating: tesseract-4.1/src/classify/shapetable.cpp
#   inflating: tesseract-4.1/src/classify/shapetable.h
#   inflating: tesseract-4.1/src/classify/tessclassifier.cpp
#   inflating: tesseract-4.1/src/classify/tessclassifier.h
#   inflating: tesseract-4.1/src/classify/trainingsample.cpp
#   inflating: tesseract-4.1/src/classify/trainingsample.h
#   inflating: tesseract-4.1/src/classify/trainingsampleset.cpp
#   inflating: tesseract-4.1/src/classify/trainingsampleset.h
#    creating: tesseract-4.1/src/cutil/
#   inflating: tesseract-4.1/src/cutil/Makefile.am
#   inflating: tesseract-4.1/src/cutil/bitvec.h
#   inflating: tesseract-4.1/src/cutil/callcpp.cpp
#   inflating: tesseract-4.1/src/cutil/callcpp.h
#   inflating: tesseract-4.1/src/cutil/cutil_class.cpp
#   inflating: tesseract-4.1/src/cutil/cutil_class.h
#   inflating: tesseract-4.1/src/cutil/emalloc.cpp
#   inflating: tesseract-4.1/src/cutil/emalloc.h
#   inflating: tesseract-4.1/src/cutil/oldlist.cpp
#   inflating: tesseract-4.1/src/cutil/oldlist.h
#    creating: tesseract-4.1/src/dict/
#   inflating: tesseract-4.1/src/dict/Makefile.am
#   inflating: tesseract-4.1/src/dict/context.cpp
#   inflating: tesseract-4.1/src/dict/dawg.cpp
#   inflating: tesseract-4.1/src/dict/dawg.h
#   inflating: tesseract-4.1/src/dict/dawg_cache.cpp
#   inflating: tesseract-4.1/src/dict/dawg_cache.h
#   inflating: tesseract-4.1/src/dict/dict.cpp
#   inflating: tesseract-4.1/src/dict/dict.h
#   inflating: tesseract-4.1/src/dict/hyphen.cpp
#   inflating: tesseract-4.1/src/dict/matchdefs.h
#   inflating: tesseract-4.1/src/dict/permdawg.cpp
#   inflating: tesseract-4.1/src/dict/stopper.cpp
#   inflating: tesseract-4.1/src/dict/stopper.h
#   inflating: tesseract-4.1/src/dict/trie.cpp
#   inflating: tesseract-4.1/src/dict/trie.h
#    creating: tesseract-4.1/src/lstm/
#   inflating: tesseract-4.1/src/lstm/Makefile.am
#   inflating: tesseract-4.1/src/lstm/convolve.cpp
#   inflating: tesseract-4.1/src/lstm/convolve.h
#   inflating: tesseract-4.1/src/lstm/ctc.cpp
#   inflating: tesseract-4.1/src/lstm/ctc.h
#   inflating: tesseract-4.1/src/lstm/fullyconnected.cpp
#   inflating: tesseract-4.1/src/lstm/fullyconnected.h
#   inflating: tesseract-4.1/src/lstm/functions.cpp
#   inflating: tesseract-4.1/src/lstm/functions.h
#   inflating: tesseract-4.1/src/lstm/generate_lut.py
#   inflating: tesseract-4.1/src/lstm/input.cpp
#   inflating: tesseract-4.1/src/lstm/input.h
#   inflating: tesseract-4.1/src/lstm/lstm.cpp
#   inflating: tesseract-4.1/src/lstm/lstm.h
#   inflating: tesseract-4.1/src/lstm/lstmrecognizer.cpp
#   inflating: tesseract-4.1/src/lstm/lstmrecognizer.h
#   inflating: tesseract-4.1/src/lstm/lstmtrainer.cpp
#   inflating: tesseract-4.1/src/lstm/lstmtrainer.h
#   inflating: tesseract-4.1/src/lstm/maxpool.cpp
#   inflating: tesseract-4.1/src/lstm/maxpool.h
#   inflating: tesseract-4.1/src/lstm/network.cpp
#   inflating: tesseract-4.1/src/lstm/network.h
#   inflating: tesseract-4.1/src/lstm/networkbuilder.cpp
#   inflating: tesseract-4.1/src/lstm/networkbuilder.h
#   inflating: tesseract-4.1/src/lstm/networkio.cpp
#   inflating: tesseract-4.1/src/lstm/networkio.h
#   inflating: tesseract-4.1/src/lstm/networkscratch.h
#   inflating: tesseract-4.1/src/lstm/parallel.cpp
#   inflating: tesseract-4.1/src/lstm/parallel.h
#   inflating: tesseract-4.1/src/lstm/plumbing.cpp
#   inflating: tesseract-4.1/src/lstm/plumbing.h
#   inflating: tesseract-4.1/src/lstm/recodebeam.cpp
#   inflating: tesseract-4.1/src/lstm/recodebeam.h
#   inflating: tesseract-4.1/src/lstm/reconfig.cpp
#   inflating: tesseract-4.1/src/lstm/reconfig.h
#   inflating: tesseract-4.1/src/lstm/reversed.cpp
#   inflating: tesseract-4.1/src/lstm/reversed.h
#   inflating: tesseract-4.1/src/lstm/series.cpp
#   inflating: tesseract-4.1/src/lstm/series.h
#   inflating: tesseract-4.1/src/lstm/static_shape.h
#   inflating: tesseract-4.1/src/lstm/stridemap.cpp
#   inflating: tesseract-4.1/src/lstm/stridemap.h
#   inflating: tesseract-4.1/src/lstm/tfnetwork.cpp
#   inflating: tesseract-4.1/src/lstm/tfnetwork.h
#   inflating: tesseract-4.1/src/lstm/tfnetwork.pb.cc
#   inflating: tesseract-4.1/src/lstm/tfnetwork.pb.h
#   inflating: tesseract-4.1/src/lstm/tfnetwork.proto
#   inflating: tesseract-4.1/src/lstm/weightmatrix.cpp
#   inflating: tesseract-4.1/src/lstm/weightmatrix.h
#    creating: tesseract-4.1/src/opencl/
#   inflating: tesseract-4.1/src/opencl/Makefile.am
#   inflating: tesseract-4.1/src/opencl/oclkernels.h
#   inflating: tesseract-4.1/src/opencl/openclwrapper.cpp
#   inflating: tesseract-4.1/src/opencl/openclwrapper.h
#    creating: tesseract-4.1/src/textord/
#   inflating: tesseract-4.1/src/textord/Makefile.am
#   inflating: tesseract-4.1/src/textord/alignedblob.cpp
#   inflating: tesseract-4.1/src/textord/alignedblob.h
#   inflating: tesseract-4.1/src/textord/baselinedetect.cpp
#   inflating: tesseract-4.1/src/textord/baselinedetect.h
#   inflating: tesseract-4.1/src/textord/bbgrid.cpp
#   inflating: tesseract-4.1/src/textord/bbgrid.h
#   inflating: tesseract-4.1/src/textord/blkocc.cpp
#   inflating: tesseract-4.1/src/textord/blkocc.h
#   inflating: tesseract-4.1/src/textord/blobgrid.cpp
#   inflating: tesseract-4.1/src/textord/blobgrid.h
#   inflating: tesseract-4.1/src/textord/ccnontextdetect.cpp
#   inflating: tesseract-4.1/src/textord/ccnontextdetect.h
#   inflating: tesseract-4.1/src/textord/cjkpitch.cpp
#   inflating: tesseract-4.1/src/textord/cjkpitch.h
#   inflating: tesseract-4.1/src/textord/colfind.cpp
#   inflating: tesseract-4.1/src/textord/colfind.h
#   inflating: tesseract-4.1/src/textord/colpartition.cpp
#   inflating: tesseract-4.1/src/textord/colpartition.h
#   inflating: tesseract-4.1/src/textord/colpartitiongrid.cpp
#   inflating: tesseract-4.1/src/textord/colpartitiongrid.h
#   inflating: tesseract-4.1/src/textord/colpartitionset.cpp
#   inflating: tesseract-4.1/src/textord/colpartitionset.h
#   inflating: tesseract-4.1/src/textord/devanagari_processing.cpp
#   inflating: tesseract-4.1/src/textord/devanagari_processing.h
#   inflating: tesseract-4.1/src/textord/drawtord.cpp
#   inflating: tesseract-4.1/src/textord/drawtord.h
#   inflating: tesseract-4.1/src/textord/edgblob.cpp
#   inflating: tesseract-4.1/src/textord/edgblob.h
#   inflating: tesseract-4.1/src/textord/edgloop.cpp
#   inflating: tesseract-4.1/src/textord/edgloop.h
#   inflating: tesseract-4.1/src/textord/equationdetectbase.cpp
#   inflating: tesseract-4.1/src/textord/equationdetectbase.h
#   inflating: tesseract-4.1/src/textord/fpchop.cpp
#   inflating: tesseract-4.1/src/textord/fpchop.h
#   inflating: tesseract-4.1/src/textord/gap_map.cpp
#   inflating: tesseract-4.1/src/textord/gap_map.h
#   inflating: tesseract-4.1/src/textord/imagefind.cpp
#   inflating: tesseract-4.1/src/textord/imagefind.h
#   inflating: tesseract-4.1/src/textord/linefind.cpp
#   inflating: tesseract-4.1/src/textord/linefind.h
#   inflating: tesseract-4.1/src/textord/makerow.cpp
#   inflating: tesseract-4.1/src/textord/makerow.h
#   inflating: tesseract-4.1/src/textord/oldbasel.cpp
#   inflating: tesseract-4.1/src/textord/oldbasel.h
#   inflating: tesseract-4.1/src/textord/pithsync.cpp
#   inflating: tesseract-4.1/src/textord/pithsync.h
#   inflating: tesseract-4.1/src/textord/pitsync1.cpp
#   inflating: tesseract-4.1/src/textord/pitsync1.h
#   inflating: tesseract-4.1/src/textord/scanedg.cpp
#   inflating: tesseract-4.1/src/textord/scanedg.h
#   inflating: tesseract-4.1/src/textord/sortflts.cpp
#   inflating: tesseract-4.1/src/textord/sortflts.h
#   inflating: tesseract-4.1/src/textord/strokewidth.cpp
#   inflating: tesseract-4.1/src/textord/strokewidth.h
#   inflating: tesseract-4.1/src/textord/tabfind.cpp
#   inflating: tesseract-4.1/src/textord/tabfind.h
#   inflating: tesseract-4.1/src/textord/tablefind.cpp
#   inflating: tesseract-4.1/src/textord/tablefind.h
#   inflating: tesseract-4.1/src/textord/tablerecog.cpp
#   inflating: tesseract-4.1/src/textord/tablerecog.h
#   inflating: tesseract-4.1/src/textord/tabvector.cpp
#   inflating: tesseract-4.1/src/textord/tabvector.h
#   inflating: tesseract-4.1/src/textord/textlineprojection.cpp
#   inflating: tesseract-4.1/src/textord/textlineprojection.h
#   inflating: tesseract-4.1/src/textord/textord.cpp
#   inflating: tesseract-4.1/src/textord/textord.h
#   inflating: tesseract-4.1/src/textord/topitch.cpp
#   inflating: tesseract-4.1/src/textord/topitch.h
#   inflating: tesseract-4.1/src/textord/tordmain.cpp
#   inflating: tesseract-4.1/src/textord/tordmain.h
#   inflating: tesseract-4.1/src/textord/tospace.cpp
#   inflating: tesseract-4.1/src/textord/tovars.cpp
#   inflating: tesseract-4.1/src/textord/tovars.h
#   inflating: tesseract-4.1/src/textord/underlin.cpp
#   inflating: tesseract-4.1/src/textord/underlin.h
#   inflating: tesseract-4.1/src/textord/wordseg.cpp
#   inflating: tesseract-4.1/src/textord/wordseg.h
#   inflating: tesseract-4.1/src/textord/workingpartset.cpp
#   inflating: tesseract-4.1/src/textord/workingpartset.h
#    creating: tesseract-4.1/src/training/
#   inflating: tesseract-4.1/src/training/CMakeLists.txt
#   inflating: tesseract-4.1/src/training/Makefile.am
#   inflating: tesseract-4.1/src/training/ambiguous_words.cpp
#   inflating: tesseract-4.1/src/training/boxchar.cpp
#   inflating: tesseract-4.1/src/training/boxchar.h
#   inflating: tesseract-4.1/src/training/classifier_tester.cpp
#   inflating: tesseract-4.1/src/training/cntraining.cpp
#   inflating: tesseract-4.1/src/training/combine_lang_model.cpp
#   inflating: tesseract-4.1/src/training/combine_tessdata.cpp
#   inflating: tesseract-4.1/src/training/commandlineflags.cpp
#   inflating: tesseract-4.1/src/training/commandlineflags.h
#   inflating: tesseract-4.1/src/training/commontraining.cpp
#   inflating: tesseract-4.1/src/training/commontraining.h
#   inflating: tesseract-4.1/src/training/dawg2wordlist.cpp
#   inflating: tesseract-4.1/src/training/degradeimage.cpp
#   inflating: tesseract-4.1/src/training/degradeimage.h
#   inflating: tesseract-4.1/src/training/errorcounter.cpp
#   inflating: tesseract-4.1/src/training/errorcounter.h
#   inflating: tesseract-4.1/src/training/fileio.cpp
#   inflating: tesseract-4.1/src/training/fileio.h
#   inflating: tesseract-4.1/src/training/icuerrorcode.cpp
#   inflating: tesseract-4.1/src/training/icuerrorcode.h
#   inflating: tesseract-4.1/src/training/lang_model_helpers.cpp
#   inflating: tesseract-4.1/src/training/lang_model_helpers.h
#   inflating: tesseract-4.1/src/training/language-specific.sh
#   inflating: tesseract-4.1/src/training/language_specific.py
#   inflating: tesseract-4.1/src/training/ligature_table.cpp
#   inflating: tesseract-4.1/src/training/ligature_table.h
#   inflating: tesseract-4.1/src/training/lstmeval.cpp
#   inflating: tesseract-4.1/src/training/lstmtester.cpp
#   inflating: tesseract-4.1/src/training/lstmtester.h
#   inflating: tesseract-4.1/src/training/lstmtraining.cpp
#   inflating: tesseract-4.1/src/training/mastertrainer.cpp
#   inflating: tesseract-4.1/src/training/mastertrainer.h
#   inflating: tesseract-4.1/src/training/merge_unicharsets.cpp
#   inflating: tesseract-4.1/src/training/mergenf.cpp
#   inflating: tesseract-4.1/src/training/mergenf.h
#   inflating: tesseract-4.1/src/training/mftraining.cpp
#   inflating: tesseract-4.1/src/training/normstrngs.cpp
#   inflating: tesseract-4.1/src/training/normstrngs.h
#   inflating: tesseract-4.1/src/training/pango_font_info.cpp
#   inflating: tesseract-4.1/src/training/pango_font_info.h
#   inflating: tesseract-4.1/src/training/set_unicharset_properties.cpp
#   inflating: tesseract-4.1/src/training/shapeclustering.cpp
#   inflating: tesseract-4.1/src/training/stringrenderer.cpp
#   inflating: tesseract-4.1/src/training/stringrenderer.h
#   inflating: tesseract-4.1/src/training/tessopt.cpp
#   inflating: tesseract-4.1/src/training/tessopt.h
#   inflating: tesseract-4.1/src/training/tesstrain.py
#   inflating: tesseract-4.1/src/training/tesstrain.sh
#   inflating: tesseract-4.1/src/training/tesstrain_utils.py
#   inflating: tesseract-4.1/src/training/tesstrain_utils.sh
#   inflating: tesseract-4.1/src/training/text2image.cpp
#   inflating: tesseract-4.1/src/training/tlog.cpp
#   inflating: tesseract-4.1/src/training/tlog.h
#   inflating: tesseract-4.1/src/training/unicharset_extractor.cpp
#   inflating: tesseract-4.1/src/training/unicharset_training_utils.cpp
#   inflating: tesseract-4.1/src/training/unicharset_training_utils.h
#   inflating: tesseract-4.1/src/training/util.h
#   inflating: tesseract-4.1/src/training/validate_grapheme.cpp
#   inflating: tesseract-4.1/src/training/validate_grapheme.h
#   inflating: tesseract-4.1/src/training/validate_indic.cpp
#   inflating: tesseract-4.1/src/training/validate_indic.h
#   inflating: tesseract-4.1/src/training/validate_javanese.cpp
#   inflating: tesseract-4.1/src/training/validate_javanese.h
#   inflating: tesseract-4.1/src/training/validate_khmer.cpp
#   inflating: tesseract-4.1/src/training/validate_khmer.h
#   inflating: tesseract-4.1/src/training/validate_myanmar.cpp
#   inflating: tesseract-4.1/src/training/validate_myanmar.h
#   inflating: tesseract-4.1/src/training/validator.cpp
#   inflating: tesseract-4.1/src/training/validator.h
#   inflating: tesseract-4.1/src/training/wordlist2dawg.cpp
#    creating: tesseract-4.1/src/viewer/
#   inflating: tesseract-4.1/src/viewer/Makefile.am
#   inflating: tesseract-4.1/src/viewer/scrollview.cpp
#   inflating: tesseract-4.1/src/viewer/scrollview.h
#   inflating: tesseract-4.1/src/viewer/svmnode.cpp
#   inflating: tesseract-4.1/src/viewer/svmnode.h
#   inflating: tesseract-4.1/src/viewer/svpaint.cpp
#   inflating: tesseract-4.1/src/viewer/svutil.cpp
#   inflating: tesseract-4.1/src/viewer/svutil.h
#    creating: tesseract-4.1/src/vs2010/
#    creating: tesseract-4.1/src/vs2010/tesseract/
#   inflating: tesseract-4.1/src/vs2010/tesseract/libtesseract.rc.in
#   inflating: tesseract-4.1/src/vs2010/tesseract/resource.h
#   inflating: tesseract-4.1/src/vs2010/tesseract/tesseract.rc.in
#    creating: tesseract-4.1/src/wordrec/
#   inflating: tesseract-4.1/src/wordrec/Makefile.am
#   inflating: tesseract-4.1/src/wordrec/associate.cpp
#   inflating: tesseract-4.1/src/wordrec/associate.h
#   inflating: tesseract-4.1/src/wordrec/chop.cpp
#   inflating: tesseract-4.1/src/wordrec/chop.h
#   inflating: tesseract-4.1/src/wordrec/chopper.cpp
#   inflating: tesseract-4.1/src/wordrec/drawfx.cpp
#   inflating: tesseract-4.1/src/wordrec/drawfx.h
#   inflating: tesseract-4.1/src/wordrec/findseam.cpp
#   inflating: tesseract-4.1/src/wordrec/findseam.h
#   inflating: tesseract-4.1/src/wordrec/gradechop.cpp
#   inflating: tesseract-4.1/src/wordrec/language_model.cpp
#   inflating: tesseract-4.1/src/wordrec/language_model.h
#   inflating: tesseract-4.1/src/wordrec/lm_consistency.cpp
#   inflating: tesseract-4.1/src/wordrec/lm_consistency.h
#   inflating: tesseract-4.1/src/wordrec/lm_pain_points.cpp
#   inflating: tesseract-4.1/src/wordrec/lm_pain_points.h
#   inflating: tesseract-4.1/src/wordrec/lm_state.cpp
#   inflating: tesseract-4.1/src/wordrec/lm_state.h
#   inflating: tesseract-4.1/src/wordrec/measure.h
#   inflating: tesseract-4.1/src/wordrec/outlines.cpp
#   inflating: tesseract-4.1/src/wordrec/outlines.h
#   inflating: tesseract-4.1/src/wordrec/params_model.cpp
#   inflating: tesseract-4.1/src/wordrec/params_model.h
#   inflating: tesseract-4.1/src/wordrec/pieces.cpp
#   inflating: tesseract-4.1/src/wordrec/plotedges.cpp
#   inflating: tesseract-4.1/src/wordrec/plotedges.h
#   inflating: tesseract-4.1/src/wordrec/render.cpp
#   inflating: tesseract-4.1/src/wordrec/render.h
#   inflating: tesseract-4.1/src/wordrec/segsearch.cpp
#   inflating: tesseract-4.1/src/wordrec/tface.cpp
#   inflating: tesseract-4.1/src/wordrec/wordclass.cpp
#   inflating: tesseract-4.1/src/wordrec/wordrec.cpp
#   inflating: tesseract-4.1/src/wordrec/wordrec.h
#   inflating: tesseract-4.1/sw.cpp
#    creating: tesseract-4.1/tessdata/
#   inflating: tesseract-4.1/tessdata/Makefile.am
#    creating: tesseract-4.1/tessdata/configs/
#   inflating: tesseract-4.1/tessdata/configs/Makefile.am
#  extracting: tesseract-4.1/tessdata/configs/alto
#   inflating: tesseract-4.1/tessdata/configs/ambigs.train
#  extracting: tesseract-4.1/tessdata/configs/api_config
#   inflating: tesseract-4.1/tessdata/configs/bazaar
#   inflating: tesseract-4.1/tessdata/configs/bigram
#   inflating: tesseract-4.1/tessdata/configs/box.train
#   inflating: tesseract-4.1/tessdata/configs/box.train.stderr
#  extracting: tesseract-4.1/tessdata/configs/digits
#  extracting: tesseract-4.1/tessdata/configs/get.images
#   inflating: tesseract-4.1/tessdata/configs/hocr
#   inflating: tesseract-4.1/tessdata/configs/inter
#   inflating: tesseract-4.1/tessdata/configs/kannada
#   inflating: tesseract-4.1/tessdata/configs/linebox
#  extracting: tesseract-4.1/tessdata/configs/logfile
#   inflating: tesseract-4.1/tessdata/configs/lstm.train
#  extracting: tesseract-4.1/tessdata/configs/lstmbox
#   inflating: tesseract-4.1/tessdata/configs/lstmdebug
#  extracting: tesseract-4.1/tessdata/configs/makebox
#  extracting: tesseract-4.1/tessdata/configs/pdf
#  extracting: tesseract-4.1/tessdata/configs/quiet
#   inflating: tesseract-4.1/tessdata/configs/rebox
#   inflating: tesseract-4.1/tessdata/configs/strokewidth
#  extracting: tesseract-4.1/tessdata/configs/tsv
#   inflating: tesseract-4.1/tessdata/configs/txt
#   inflating: tesseract-4.1/tessdata/configs/unlv
#  extracting: tesseract-4.1/tessdata/configs/wordstrbox
#   inflating: tesseract-4.1/tessdata/eng.user-patterns
#  extracting: tesseract-4.1/tessdata/eng.user-words
#   inflating: tesseract-4.1/tessdata/pdf.ttf
#    creating: tesseract-4.1/tessdata/tessconfigs/
#   inflating: tesseract-4.1/tessdata/tessconfigs/Makefile.am
#   inflating: tesseract-4.1/tessdata/tessconfigs/batch
#   inflating: tesseract-4.1/tessdata/tessconfigs/batch.nochop
#   inflating: tesseract-4.1/tessdata/tessconfigs/matdemo
#   inflating: tesseract-4.1/tessdata/tessconfigs/msdemo
#  extracting: tesseract-4.1/tessdata/tessconfigs/nobatch
#   inflating: tesseract-4.1/tessdata/tessconfigs/segdemo
#   inflating: tesseract-4.1/tesseract.pc.cmake
#   inflating: tesseract-4.1/tesseract.pc.in
#    creating: tesseract-4.1/test/
#    creating: tesseract-4.1/unittest/
#   inflating: tesseract-4.1/unittest/Makefile.am
#   inflating: tesseract-4.1/unittest/README.md
#   inflating: tesseract-4.1/unittest/apiexample_test.cc
#   inflating: tesseract-4.1/unittest/applybox_test.cc
#   inflating: tesseract-4.1/unittest/baseapi_test.cc
#   inflating: tesseract-4.1/unittest/baseapi_thread_test.cc
#   inflating: tesseract-4.1/unittest/bitvector_test.cc
#   inflating: tesseract-4.1/unittest/cleanapi_test.cc
#   inflating: tesseract-4.1/unittest/colpartition_test.cc
#   inflating: tesseract-4.1/unittest/commandlineflags_test.cc
#   inflating: tesseract-4.1/unittest/cycletimer.h
#   inflating: tesseract-4.1/unittest/dawg_test.cc
#   inflating: tesseract-4.1/unittest/denorm_test.cc
#   inflating: tesseract-4.1/unittest/equationdetect_test.cc
#   inflating: tesseract-4.1/unittest/fileio_test.cc
#    creating: tesseract-4.1/unittest/fuzzers/
#   inflating: tesseract-4.1/unittest/fuzzers/fuzzer-api.cpp
#   inflating: tesseract-4.1/unittest/heap_test.cc
#   inflating: tesseract-4.1/unittest/imagedata_test.cc
#   inflating: tesseract-4.1/unittest/include_gunit.h
#   inflating: tesseract-4.1/unittest/indexmapbidi_test.cc
#   inflating: tesseract-4.1/unittest/intfeaturemap_test.cc
#   inflating: tesseract-4.1/unittest/intsimdmatrix_test.cc
#   inflating: tesseract-4.1/unittest/lang_model_test.cc
#   inflating: tesseract-4.1/unittest/layout_test.cc
#   inflating: tesseract-4.1/unittest/ligature_table_test.cc
#   inflating: tesseract-4.1/unittest/linlsq_test.cc
#   inflating: tesseract-4.1/unittest/loadlang_test.cc
#   inflating: tesseract-4.1/unittest/log.h
#   inflating: tesseract-4.1/unittest/lstm_recode_test.cc
#   inflating: tesseract-4.1/unittest/lstm_squashed_test.cc
#   inflating: tesseract-4.1/unittest/lstm_test.cc
#   inflating: tesseract-4.1/unittest/lstm_test.h
#   inflating: tesseract-4.1/unittest/lstmtrainer_test.cc
#   inflating: tesseract-4.1/unittest/mastertrainer_test.cc
#   inflating: tesseract-4.1/unittest/matrix_test.cc
#   inflating: tesseract-4.1/unittest/networkio_test.cc
#   inflating: tesseract-4.1/unittest/normstrngs_test.cc
#   inflating: tesseract-4.1/unittest/normstrngs_test.h
#   inflating: tesseract-4.1/unittest/nthitem_test.cc
#   inflating: tesseract-4.1/unittest/osd_test.cc
#   inflating: tesseract-4.1/unittest/pagesegmode_test.cc
#   inflating: tesseract-4.1/unittest/pango_font_info_test.cc
#   inflating: tesseract-4.1/unittest/paragraphs_test.cc
#   inflating: tesseract-4.1/unittest/params_model_test.cc
#   inflating: tesseract-4.1/unittest/progress_test.cc
#   inflating: tesseract-4.1/unittest/qrsequence_test.cc
#   inflating: tesseract-4.1/unittest/recodebeam_test.cc
#   inflating: tesseract-4.1/unittest/rect_test.cc
#   inflating: tesseract-4.1/unittest/resultiterator_test.cc
#   inflating: tesseract-4.1/unittest/scanutils_test.cc
#   inflating: tesseract-4.1/unittest/shapetable_test.cc
#   inflating: tesseract-4.1/unittest/stats_test.cc
#   inflating: tesseract-4.1/unittest/stridemap_test.cc
#   inflating: tesseract-4.1/unittest/stringrenderer_test.cc
#   inflating: tesseract-4.1/unittest/tablefind_test.cc
#   inflating: tesseract-4.1/unittest/tablerecog_test.cc
#   inflating: tesseract-4.1/unittest/tabvector_test.cc
#   inflating: tesseract-4.1/unittest/tatweel_test.cc
#   inflating: tesseract-4.1/unittest/textlineprojection_test.cc
#   inflating: tesseract-4.1/unittest/tfile_test.cc
#   inflating: tesseract-4.1/unittest/unichar_test.cc
#   inflating: tesseract-4.1/unittest/unicharcompress_test.cc
#   inflating: tesseract-4.1/unittest/unicharset_test.cc
#   inflating: tesseract-4.1/unittest/validate_grapheme_test.cc
#   inflating: tesseract-4.1/unittest/validate_indic_test.cc
#   inflating: tesseract-4.1/unittest/validate_khmer_test.cc
#   inflating: tesseract-4.1/unittest/validate_myanmar_test.cc
#   inflating: tesseract-4.1/unittest/validator_test.cc

# %%
# !git clone https://github.com/tesseract-ocr/tessdata_best
# Out:
# Cloning into 'tessdata_best'...
# remote: Enumerating objects: 254, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 254 (delta 0), reused 2 (delta 0), pack-reused 250
# Receiving objects: 100% (254/254), 1.30 GiB | 35.48 MiB/s, done.
# Resolving deltas: 100% (41/41), done.
# Checking out files: 100% (167/167), done.

# %%
# !chmod 755 -R /content/tesseract/src/training/tesstrain.sh

# %%
# !combine_tessdata -e /content/tessdata_best/eng.traineddata eng.lstm
# Out:
# Extracting tessdata components from /content/tessdata_best/eng.traineddata
# Wrote eng.lstm
# Version string:4.00.00alpha:eng:synth20170629:[1,36,0,1Ct3,3,16Mp3,3Lfys64Lfx96Lrx96Lfx512O1c1]
# 17:lstm:size=11689099, offset=192
# 18:lstm-punc-dawg:size=4322, offset=11689291
# 19:lstm-word-dawg:size=3694794, offset=11693613
# 20:lstm-number-dawg:size=4738, offset=15388407
# 21:lstm-unicharset:size=6360, offset=15393145
# 22:lstm-recoder:size=1012, offset=15399505
# 23:version:size=80, offset=15400517

# %%
# !cp /content/tessdata_best/eng.traineddata /content/tesseract/tessdata

# %%
! /content/tesseract/src/training/tesstrain.sh --fonts_dir fonts \
	--fontlist '{font_name}' \
	--lang eng \
	--linedata_only \
	--langdata_dir /content/langdata_lstm \
	--tessdata_dir /content/tesseract/tessdata \
	--save_box_tiff \
	--maxpages 10 \
	--output_dir train
# Out:
# === Starting training for language 'eng'
# [Fri Jul 1 11:55:14 UTC 2022] /usr/bin/text2image --fonts_dir=fonts --ptsize 12 --font=Baby Shower --outputbase=/tmp/font_tmp.nLC56cw67o/sample_text.txt --text=/tmp/font_tmp.nLC56cw67o/sample_text.txt --fontconfig_tmpdir=/tmp/font_tmp.nLC56cw67o
# Rendered page 0 to file /tmp/font_tmp.nLC56cw67o/sample_text.txt.tif
#
# === Phase I: Generating training images ===
# Rendering using Baby Shower
# [Fri Jul 1 11:55:16 UTC 2022] /usr/bin/text2image --fontconfig_tmpdir=/tmp/font_tmp.nLC56cw67o --fonts_dir=fonts --strip_unrenderable_words --leading=32 --xsize=3600 --char_spacing=0.0 --exposure=0 --outputbase=/tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0 --max_pages=10 --font=Baby Shower --ptsize 12 --text=/content/langdata_lstm/eng/eng.training_text
# Rendered page 0 to file /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.tif
# Rendered page 1 to file /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.tif
# Rendered page 2 to file /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.tif
# Rendered page 3 to file /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.tif
# Rendered page 4 to file /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.tif
# Rendered page 5 to file /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.tif
# Rendered page 6 to file /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.tif
# Rendered page 7 to file /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.tif
# Rendered page 8 to file /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.tif
# Rendered page 9 to file /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.tif
#
# === Phase UP: Generating unicharset and unichar properties files ===
# [Fri Jul 1 11:55:21 UTC 2022] /usr/bin/unicharset_extractor --output_unicharset /tmp/eng-2022-07-01.vuZ/eng.unicharset --norm_mode 1 /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.box
# Extracting unicharset from box file /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.box
# Other case É of é is not in unicharset
# Wrote unicharset file /tmp/eng-2022-07-01.vuZ/eng.unicharset
# [Fri Jul 1 11:55:21 UTC 2022] /usr/bin/set_unicharset_properties -U /tmp/eng-2022-07-01.vuZ/eng.unicharset -O /tmp/eng-2022-07-01.vuZ/eng.unicharset -X /tmp/eng-2022-07-01.vuZ/eng.xheights --script_dir=/content/langdata_lstm
# Loaded unicharset of size 112 from file /tmp/eng-2022-07-01.vuZ/eng.unicharset
# Setting unichar properties
# Other case É of é is not in unicharset
# Setting script properties
# Warning: properties incomplete for index 78 = ~
# Writing unicharset to file /tmp/eng-2022-07-01.vuZ/eng.unicharset
#
# === Phase E: Generating lstmf files ===
# Using TESSDATA_PREFIX=/content/tesseract/tessdata
# [Fri Jul 1 11:55:21 UTC 2022] /usr/bin/tesseract /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.tif /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0 --psm 6 lstm.train
# Tesseract Open Source OCR Engine v4.0.0-beta.1 with Leptonica
# Page 1
# Page 2
# Loaded 40/40 pages (1-40) of document /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.lstmf
# Page 3
# Loaded 80/80 pages (1-80) of document /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.lstmf
# Page 4
# Loaded 120/120 pages (1-120) of document /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.lstmf
# Page 5
# Loaded 160/160 pages (1-160) of document /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.lstmf
# Page 6
# Loaded 200/200 pages (1-200) of document /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.lstmf
# Page 7
# Loaded 240/240 pages (1-240) of document /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.lstmf
# Page 8
# Loaded 280/280 pages (1-280) of document /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.lstmf
# Page 9
# Loaded 320/320 pages (1-320) of document /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.lstmf
# Page 10
# Loaded 360/360 pages (1-360) of document /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.lstmf
#
# === Constructing LSTM training data ===
# [Fri Jul 1 11:55:26 UTC 2022] /usr/bin/combine_lang_model --input_unicharset /tmp/eng-2022-07-01.vuZ/eng.unicharset --script_dir /content/langdata_lstm --words /content/langdata_lstm/eng/eng.wordlist --numbers /content/langdata_lstm/eng/eng.numbers --puncs /content/langdata_lstm/eng/eng.punc --output_dir train --lang eng
# Loaded unicharset of size 112 from file /tmp/eng-2022-07-01.vuZ/eng.unicharset
# Setting unichar properties
# Other case É of é is not in unicharset
# Setting script properties
# Warning: properties incomplete for index 78 = ~
# Config file is optional, continuing...
# Failed to read data from: /content/langdata_lstm/eng/eng.config
# Null char=2
# Reducing Trie to SquishedDawg
# Reducing Trie to SquishedDawg
# Reducing Trie to SquishedDawg
#
# === Saving box/tiff pairs for training data ===
# Moving /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.box to train
# Moving /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.tif to train
#
# === Moving lstmf files for training data ===
# Moving /tmp/eng-2022-07-01.vuZ/eng.Baby_Shower.exp0.lstmf to train
#
# Created starter traineddata for LSTM training of language 'eng'
#
#
# Run 'lstmtraining' command to continue LSTM training for language 'eng'

# %%
# %%shell
#
# OMP_THREAD_LIMIT=16 lstmtraining \
# 	--continue_from eng.lstm \
# 	--model_output output/font_name \
# 	--traineddata /content/tesseract/tessdata/eng.traineddata \
# 	--train_listfile train/eng.training_files.txt \
# 	--max_iterations 1000
# Out:
# Loaded file eng.lstm, unpacking...
# Warning: LSTMTrainer deserialized an LSTMRecognizer!
# Continuing from eng.lstm
# Loaded 400/400 pages (1-400) of document train/eng.Baby_Shower.exp0.lstmf
# 2 Percent improvement time=98, best error was 100 @ 0
# At iteration 98/100/100, Mean rms=1.774%, delta=4.89%, char train=13.804%, word train=34.909%, skip ratio=0%,  New best char error = 13.804 wrote best model:output/font_name13.804_98.checkpoint wrote checkpoint.
#
# 2 Percent improvement time=96, best error was 13.804 @ 98
# At iteration 194/200/200, Mean rms=1.548%, delta=3.746%, char train=10.672%, word train=29.459%, skip ratio=0%,  New best char error = 10.672 wrote best model:output/font_name10.672_194.checkpoint wrote checkpoint.
#
# 2 Percent improvement time=191, best error was 13.804 @ 98
# At iteration 289/300/300, Mean rms=1.439%, delta=3.288%, char train=9.455%, word train=27.568%, skip ratio=0%,  New best char error = 9.455 Transitioned to stage 1 wrote best model:output/font_name9.455_289.checkpoint wrote checkpoint.
#
# 2 Percent improvement time=179, best error was 10.672 @ 194
# At iteration 373/400/400, Mean rms=1.349%, delta=2.926%, char train=8.444%, word train=25.102%, skip ratio=0%,  New best char error = 8.444 wrote best model:output/font_name8.444_373.checkpoint wrote checkpoint.
#
# 2 Percent improvement time=264, best error was 10.672 @ 194
# At iteration 458/500/500, Mean rms=1.266%, delta=2.621%, char train=7.635%, word train=23.158%, skip ratio=0%,  New best char error = 7.635 wrote best model:output/font_name7.635_458.checkpoint wrote checkpoint.
#
# 2 Percent improvement time=251, best error was 9.455 @ 289
# At iteration 540/600/600, Mean rms=1.2%, delta=2.375%, char train=6.965%, word train=21.342%, skip ratio=0%,  New best char error = 6.965 wrote best model:output/font_name6.965_540.checkpoint wrote checkpoint.
#
# 2 Percent improvement time=246, best error was 8.444 @ 373
# At iteration 619/700/700, Mean rms=1.149%, delta=2.195%, char train=6.441%, word train=20.013%, skip ratio=0%,  New best char error = 6.441 wrote best model:output/font_name6.441_619.checkpoint wrote checkpoint.
#
# 2 Percent improvement time=318, best error was 8.444 @ 373
# At iteration 691/800/800, Mean rms=1.103%, delta=2.037%, char train=6.009%, word train=18.803%, skip ratio=0%,  New best char error = 6.009 wrote best model:output/font_name6.009_691.checkpoint wrote checkpoint.
#
# 2 Percent improvement time=296, best error was 7.635 @ 458
# At iteration 754/900/900, Mean rms=1.058%, delta=1.894%, char train=5.619%, word train=17.722%, skip ratio=0%,  New best char error = 5.619 wrote best model:output/font_name5.619_754.checkpoint wrote checkpoint.
#
# 2 Percent improvement time=355, best error was 7.635 @ 458
# At iteration 813/1000/1000, Mean rms=1.017%, delta=1.773%, char train=5.28%, word train=16.746%, skip ratio=0%,  New best char error = 5.28 wrote best model:output/font_name5.28_813.checkpoint wrote checkpoint.
#
# Finished! Error rate = 5.28

# %%
# %%shell
#
# lstmtraining --stop_training \
# 	--continue_from output/font_name_checkpoint \
# 	--traineddata /content/tesseract/tessdata/eng.traineddata \
# 	--model_output output/font_name.traineddata
# Out:
# Loaded file output/font_name_checkpoint, unpacking...
